# %%
import matplotlib as plt
import numpy as np 
import pandas as pd
from scipy.optimize import curve_fit
import glob
import os

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/anaconda3/lib/python3.7/site-packages (0.8.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
#use of glob to get all .txt files in the folder
path = os.getcwd()
txt_files = glob.glob(os.path.join(path, "*.txt"))
#print(txt_files)
data_frames = []

for file in txt_files: 
    df = pd.read_csv(file)
    #display(df)
    del df['Unnamed: 5']
    #df.dropna()
    #display(df)
    #data_frames.append(df)
    print(len(data_frames))
    display(df)
# Out:
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.600000E+01       -1.086762e-07
# 1                      -4.590000E+01       -9.301785e-08
# 2                      -4.580000E+01       -8.140054e-08
# 3                      -4.570000E+01       -7.938017e-08
# 4                      -4.560000E+01       -7.786470e-08
# ..                               ...                 ...
# 608  3.421947\t437.296241\t55.601000                 NaN
# 609  3.433464\t436.432409\t55.701000                 NaN
# 610  3.432112\t436.562767\t55.801000                 NaN
# 611  3.420810\t437.461195\t55.901000                 NaN
# 612  3.425165\t437.175125\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     3401.726        21508.0
# 1                            9.910000e+37     3402.783        21508.0
# 2                            9.910000e+37     3403.843        21508.0
# 3                            9.910000e+37     3404.904        21508.0
# 4                            9.910000e+37     3405.966        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.000000E+01       -6.625168e-08
# 1                      -2.980000E+01       -3.240762e-08
# 2                      -2.960000E+01       -3.109761e-09
# 3                      -2.940000E+01        2.315503e-08
# 4                      -2.920000E+01        3.174145e-08
# ..                               ...                 ...
# 333  1.663783\t713.538764\t30.602000                 NaN
# 334  1.674625\t712.727531\t30.702000                 NaN
# 335  1.670688\t713.123730\t30.802000                 NaN
# 336  1.661537\t713.719996\t30.902000                 NaN
# 337  1.670442\t713.064961\t31.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     1158.393        21508.0
# 1                            9.910000e+37     1159.449        21508.0
# 2                            9.910000e+37     1160.511        21508.0
# 3                            9.910000e+37     1161.569        21508.0
# 4                            9.910000e+37     1162.630        21508.0
# ..                                    ...          ...            ...
# 333                                   NaN          NaN            NaN
# 334                                   NaN          NaN            NaN
# 335                                   NaN          NaN            NaN
# 336                                   NaN          NaN            NaN
# 337                                   NaN          NaN            NaN
#
# [338 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.600000E+01       -1.076657e-07
# 1                      -4.590000E+01       -8.039020e-08
# 2                      -4.580000E+01       -8.392585e-08
# 3                      -4.570000E+01       -7.432895e-08
# 4                      -4.560000E+01       -7.079324e-08
# ..                               ...                 ...
# 608  3.412949\t436.182666\t55.601000                 NaN
# 609  3.424136\t435.348351\t55.701000                 NaN
# 610  3.422853\t435.425501\t55.801000                 NaN
# 611  3.411833\t436.268927\t55.901000                 NaN
# 612  3.414864\t436.044366\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     3489.894        21508.0
# 1                            9.910000e+37     3490.951        21508.0
# 2                            9.910000e+37     3492.010        21508.0
# 3                            9.910000e+37     3493.067        21508.0
# 4                            9.910000e+37     3494.124        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.600000E+01       -1.076659e-07
# 1                      -4.590000E+01       -8.796698e-08
# 2                      -4.580000E+01       -8.039042e-08
# 3                      -4.570000E+01       -7.533935e-08
# 4                      -4.560000E+01       -7.230871e-08
# ..                               ...                 ...
# 608  3.406459\t437.368683\t55.601000                 NaN
# 609  3.415878\t436.667430\t55.701000                 NaN
# 610  3.407949\t437.260742\t55.801000                 NaN
# 611  3.400553\t437.833562\t55.901000                 NaN
# 612  3.409913\t437.125844\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     3259.372        21508.0
# 1                            9.910000e+37     3260.432        21508.0
# 2                            9.910000e+37     3261.510        21508.0
# 3                            9.910000e+37     3262.569        21508.0
# 4                            9.910000e+37     3263.627        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.300000E+01       -7.837227e-08
# 1                      -3.290000E+01       -4.857032e-08
# 2                      -3.280000E+01       -3.543726e-08
# 3                      -3.270000E+01       -2.583997e-08
# 4                      -3.260000E+01       -1.523248e-08
# ..                               ...                 ...
# 608  1.930220\t674.672550\t55.602000                 NaN
# 609  1.933408\t674.431217\t55.702000                 NaN
# 610  1.942557\t673.729212\t55.802000                 NaN
# 611  1.933512\t674.362210\t55.902000                 NaN
# 612  1.932247\t674.407300\t56.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     2255.545        21508.0
# 1                            9.910000e+37     2256.604        21508.0
# 2                            9.910000e+37     2257.663        21508.0
# 3                            9.910000e+37     2258.722        21508.0
# 4                            9.910000e+37     2259.808        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.300000E+01       -1.425272e-07
# 1                      -4.290000E+01       -1.339399e-07
# 2                      -4.280000E+01       -1.374758e-07
# 3                      -4.270000E+01       -1.203012e-07
# 4                      -4.260000E+01       -1.258577e-07
# ..                               ...                 ...
# 608  3.258937\t473.732282\t55.601000                 NaN
# 609  3.269367\t473.003833\t55.701000                 NaN
# 610  3.271103\t472.811476\t55.801000                 NaN
# 611  3.260292\t473.588614\t55.901000                 NaN
# 612  3.262211\t473.465840\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     513.2354        21508.0
# 1                            9.910000e+37     514.2949        21508.0
# 2                            9.910000e+37     515.3662        21508.0
# 3                            9.910000e+37     516.4248        21508.0
# 4                            9.910000e+37     517.4883        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.300000E+01       -1.667700e-07
# 1                      -4.290000E+01       -1.425242e-07
# 2                      -4.280000E+01       -1.354524e-07
# 3                      -4.270000E+01       -1.314113e-07
# 4                      -4.260000E+01       -1.268652e-07
# ..                               ...                 ...
# 608  3.256401\t471.141379\t55.602000                 NaN
# 609  3.246563\t471.899555\t55.702000                 NaN
# 610  3.251119\t471.587092\t55.802000                 NaN
# 611  3.258163\t471.082743\t55.902000                 NaN
# 612  3.250755\t471.553318\t56.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     969.2773        21508.0
# 1                            9.910000e+37     970.3330        21508.0
# 2                            9.910000e+37     971.3926        21508.0
# 3                            9.910000e+37     972.4512        21508.0
# 4                            9.910000e+37     973.5088        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.300000E+01       -1.586904e-07
# 1                      -4.290000E+01       -1.364646e-07
# 2                      -4.280000E+01       -1.283824e-07
# 3                      -4.270000E+01       -1.223209e-07
# 4                      -4.260000E+01       -1.177747e-07
# ..                               ...                 ...
# 608  3.260608\t473.488585\t55.601000                 NaN
# 609  3.271013\t472.625394\t55.702000                 NaN
# 610  3.269448\t472.668148\t55.801000                 NaN
# 611  3.259248\t473.525782\t55.901000                 NaN
# 612  3.263470\t473.230622\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     639.5488        21508.0
# 1                            9.910000e+37     640.6074        21508.0
# 2                            9.910000e+37     641.6689        21508.0
# 3                            9.910000e+37     642.7471        21508.0
# 4                            9.910000e+37     643.8037        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.300000E+01       -2.809329e-07
# 1                      -3.290000E+01       -2.597169e-07
# 2                      -3.280000E+01       -2.450681e-07
# 3                      -3.270000E+01       -2.369859e-07
# 4                      -3.260000E+01       -2.218319e-07
# ..                               ...                 ...
# 608  1.684606\t711.323425\t55.601000                 NaN
# 609  1.693356\t710.743648\t55.701000                 NaN
# 610  1.683374\t711.355574\t55.801000                 NaN
# 611  1.681128\t711.555866\t55.902000                 NaN
# 612  1.691896\t710.717081\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     1317.751        21508.0
# 1                            9.910000e+37     1318.808        21508.0
# 2                            9.910000e+37     1319.868        21508.0
# 3                            9.910000e+37     1320.930        21508.0
# 4                            9.910000e+37     1321.991        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.300000E+01       -2.309217e-07
# 1                      -3.290000E+01       -2.076859e-07
# 2                      -3.280000E+01       -1.945526e-07
# 3                      -3.270000E+01       -1.799039e-07
# 4                      -3.260000E+01       -1.728321e-07
# ..                               ...                 ...
# 608  1.697172\t710.502886\t55.601000                 NaN
# 609  1.702432\t709.992731\t55.701000                 NaN
# 610  1.691972\t710.756228\t55.801000                 NaN
# 611  1.691326\t710.826760\t55.901000                 NaN
# 612  1.701659\t710.187285\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     1641.278        21508.0
# 1                            9.910000e+37     1642.336        21508.0
# 2                            9.910000e+37     1643.392        21508.0
# 3                            9.910000e+37     1644.450        21508.0
# 4                            9.910000e+37     1645.508        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                                NaN              -43.69
# 1                                NaN              -43.68
# 2                                NaN              -43.67
# 3                                NaN              -43.66
# 4                                NaN              -43.65
# ..                               ...                 ...
# 608  3.429600\t443.398455\t55.602000                 NaN
# 609  3.439576\t442.653656\t55.702000                 NaN
# 610  3.434234\t443.015138\t55.802000                 NaN
# 611  3.426131\t443.606731\t55.902000                 NaN
# 612  3.433692\t443.070658\t56.002000                 NaN
#
#       resistance (9.9e37 if not enabled)     timestamp    status word
# 0                           -1.422189e-08  9.910000e+37       2693.040
# 1                           -1.927296e-08  9.910000e+37       2694.101
# 2                           -1.826275e-08  9.910000e+37       2695.176
# 3                           -1.624231e-08  9.910000e+37       2696.235
# 4                           -1.321168e-08  9.910000e+37       2697.295
# ..                                    ...           ...            ...
# 608                                   NaN           NaN            NaN
# 609                                   NaN           NaN            NaN
# 610                                   NaN           NaN            NaN
# 611                                   NaN           NaN            NaN
# 612                                   NaN           NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                      probe voltage (V)   probe current (A)  \
# 0                        -4.600000E+01       -1.142334e-07
# 1                        -4.599000E+01       -9.150354e-08
# 2                        -4.598000E+01       -8.897806e-08
# 3                        -4.597000E+01       -8.342188e-08
# 4                        -4.596000E+01       -8.746269e-08
# ...                                ...                 ...
# 2227  3.401317\t442.430991\t216.702000                 NaN
# 2228  3.398057\t442.710702\t216.802000                 NaN
# 2229  3.388188\t443.486833\t216.902000                 NaN
# 2230  3.394598\t443.030876\t217.002000                 NaN
# 2231  3.402935\t442.389640\t217.102000                 NaN
#
#        resistance (9.9e37 if not enabled)    timestamp    status word
# 0                             9.910000e+37     2447.528        21508.0
# 1                             9.910000e+37     2448.604        21508.0
# 2                             9.910000e+37     2449.681        21508.0
# 3                             9.910000e+37     2450.752        21508.0
# 4                             9.910000e+37     2451.811        21508.0
# ...                                    ...          ...            ...
# 2227                                   NaN          NaN            NaN
# 2228                                   NaN          NaN            NaN
# 2229                                   NaN          NaN            NaN
# 2230                                   NaN          NaN            NaN
# 2231                                   NaN          NaN            NaN
#
# [2232 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -4.300000E+01       -1.637389e-07
# 1                      -4.290000E+01       -1.440391e-07
# 2                      -4.280000E+01       -1.369672e-07
# 3                      -4.270000E+01       -1.319161e-07
# 4                      -4.260000E+01       -1.253494e-07
# ..                               ...                 ...
# 608  3.211844\t469.502351\t55.601000                 NaN
# 609  3.205571\t470.227361\t55.701000                 NaN
# 610  3.214435\t469.736214\t55.801000                 NaN
# 611  3.222888\t469.256217\t55.901000                 NaN
# 612  3.214784\t469.975760\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     1091.029        21508.0
# 1                            9.910000e+37     1092.088        21508.0
# 2                            9.910000e+37     1093.146        21508.0
# 3                            9.910000e+37     1094.225        21508.0
# 4                            9.910000e+37     1095.304        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.300000E+01       -2.607260e-07
# 1                      -3.290000E+01       -2.364799e-07
# 2                      -3.280000E+01       -2.198106e-07
# 3                      -3.270000E+01       -2.132440e-07
# 4                      -3.260000E+01       -1.960695e-07
# ..                               ...                 ...
# 608  1.696946\t710.174210\t55.602000                 NaN
# 609  1.691143\t710.610049\t55.702000                 NaN
# 610  1.680552\t711.432634\t55.802000                 NaN
# 611  1.694207\t710.388590\t55.902000                 NaN
# 612  1.694127\t710.384354\t56.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     1421.969        21508.0
# 1                            9.910000e+37     1423.046        21508.0
# 2                            9.910000e+37     1424.105        21508.0
# 3                            9.910000e+37     1425.182        21508.0
# 4                            9.910000e+37     1426.242        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -6.000000E+01       -6.163132e-07
# 1                      -5.900000E+01       -5.799454e-07
# 2                      -5.800000E+01       -5.440825e-07
# 3                      -5.700000E+01       -5.021586e-07
# 4                      -5.600000E+01       -4.668006e-07
# ..                               ...                 ...
# 716  3.378117\t446.822872\t65.603000                 NaN
# 717  3.388644\t446.120456\t65.702000                 NaN
# 718  3.385426\t446.128176\t65.802000                 NaN
# 719  3.373023\t446.830083\t65.902000                 NaN
# 720  3.377967\t446.315732\t66.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     2226.273        21508.0
# 1                            9.910000e+37     2227.333        21508.0
# 2                            9.910000e+37     2228.392        21508.0
# 3                            9.910000e+37     2229.479        21508.0
# 4                            9.910000e+37     2230.541        21508.0
# ..                                    ...          ...            ...
# 716                                   NaN          NaN            NaN
# 717                                   NaN          NaN            NaN
# 718                                   NaN          NaN            NaN
# 719                                   NaN          NaN            NaN
# 720                                   NaN          NaN            NaN
#
# [721 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -5.900000E+01           -0.000005
# 1                      -5.800000E+01           -0.000005
# 2                      -5.700000E+01           -0.000005
# 3                      -5.600000E+01           -0.000005
# 4                      -5.500000E+01           -0.000004
# ..                               ...                 ...
# 706  1.626469\t719.177623\t64.601000                 NaN
# 707  1.615254\t720.172736\t64.701000                 NaN
# 708  1.618236\t719.935643\t64.801000                 NaN
# 709  1.626146\t719.214372\t64.901000                 NaN
# 710  1.617163\t719.902277\t65.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     882.7227        21508.0
# 1                            9.910000e+37     883.7822        21508.0
# 2                            9.910000e+37     884.8408        21508.0
# 3                            9.910000e+37     885.9014        21508.0
# 4                            9.910000e+37     886.9590        21508.0
# ..                                    ...          ...            ...
# 706                                   NaN          NaN            NaN
# 707                                   NaN          NaN            NaN
# 708                                   NaN          NaN            NaN
# 709                                   NaN          NaN            NaN
# 710                                   NaN          NaN            NaN
#
# [711 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -6.000000E+01       -1.026041e-06
# 1                      -5.900000E+01       -1.006844e-06
# 2                      -5.800000E+01       -9.699686e-07
# 3                      -5.700000E+01       -9.290509e-07
# 4                      -5.600000E+01       -8.845968e-07
# ..                               ...                 ...
# 716  3.269607\t473.220335\t65.602000                 NaN
# 717  3.266822\t473.438494\t65.702000                 NaN
# 718  3.259335\t473.904497\t65.802000                 NaN
# 719  3.265318\t473.498051\t65.902000                 NaN
# 720  3.269184\t473.244509\t66.002000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     211.4736        21508.0
# 1                            9.910000e+37     212.5361        21508.0
# 2                            9.910000e+37     213.5957        21508.0
# 3                            9.910000e+37     214.6553        21508.0
# 4                            9.910000e+37     215.7139        21508.0
# ..                                    ...          ...            ...
# 716                                   NaN          NaN            NaN
# 717                                   NaN          NaN            NaN
# 718                                   NaN          NaN            NaN
# 719                                   NaN          NaN            NaN
# 720                                   NaN          NaN            NaN
#
# [721 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.500000E+01       -2.551631e-07
# 1                      -3.490000E+01       -2.299073e-07
# 2                      -3.480000E+01       -2.147538e-07
# 3                      -3.470000E+01       -2.091975e-07
# 4                      -3.460000E+01       -1.975798e-07
# ..                               ...                 ...
# 608  1.936708\t674.383017\t55.604000                 NaN
# 609  1.932550\t674.726339\t55.706000                 NaN
# 610  1.943143\t673.990963\t55.804000                 NaN
# 611  1.942802\t674.019856\t55.904000                 NaN
# 612  1.932540\t674.797083\t56.004000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     2388.359        21508.0
# 1                            9.910000e+37     2389.418        21508.0
# 2                            9.910000e+37     2390.478        21508.0
# 3                            9.910000e+37     2391.539        21508.0
# 4                            9.910000e+37     2392.618        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.500000E+01       -2.531414e-07
# 1                      -3.490000E+01       -2.258655e-07
# 2                      -3.480000E+01       -2.152581e-07
# 3                      -3.470000E+01       -2.086914e-07
# 4                      -3.460000E+01       -1.950534e-07
# ..                               ...                 ...
# 608  1.936546\t675.296721\t55.604000                 NaN
# 609  1.931484\t675.654282\t55.704000                 NaN
# 610  1.941606\t674.888045\t55.804000                 NaN
# 611  1.941803\t674.823015\t55.904000                 NaN
# 612  1.932527\t675.559950\t56.004000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     2575.760        21508.0
# 1                            9.910000e+37     2576.818        21508.0
# 2                            9.910000e+37     2577.876        21508.0
# 3                            9.910000e+37     2578.936        21508.0
# 4                            9.910000e+37     2579.998        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]
# 0
#                    probe voltage (V)   probe current (A)  \
# 0                      -3.500000E+01       -2.516267e-07
# 1                      -3.490000E+01       -2.288967e-07
# 2                      -3.480000E+01       -2.152583e-07
# 3                      -3.470000E+01       -2.056614e-07
# 4                      -3.460000E+01       -1.960640e-07
# ..                               ...                 ...
# 608  1.943395\t674.484822\t55.601000                 NaN
# 609  1.938131\t674.874225\t55.701000                 NaN
# 610  1.930458\t675.455729\t55.801000                 NaN
# 611  1.939639\t674.725269\t55.901000                 NaN
# 612  1.943139\t674.499495\t56.001000                 NaN
#
#       resistance (9.9e37 if not enabled)    timestamp    status word
# 0                            9.910000e+37     2485.757        21508.0
# 1                            9.910000e+37     2486.816        21508.0
# 2                            9.910000e+37     2487.893        21508.0
# 3                            9.910000e+37     2488.954        21508.0
# 4                            9.910000e+37     2490.030        21508.0
# ..                                    ...          ...            ...
# 608                                   NaN          NaN            NaN
# 609                                   NaN          NaN            NaN
# 610                                   NaN          NaN            NaN
# 611                                   NaN          NaN            NaN
# 612                                   NaN          NaN            NaN
#
# [613 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
for i in range(len(data_frames)):
#     print(type(i))
#     print(i.keys())
    probe_voltage = data_frames[i]['probe voltage (V)']
    probe_current = data_frames[i][' probe current (A)']
    plt.plot(probe_voltage, probe_current)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
len(data_frames[0])

# %%
data_frames[0][' probe current (A)']
