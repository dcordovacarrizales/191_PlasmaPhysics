# %%
#pip install mpld3

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import scipy
from scipy.optimize import curve_fit
from scipy.signal import find_peaks
from scipy.signal import savgol_filter
import glob
import os
#from sklearn.linear_model import LinearRegression

from scipy.optimize import curve_fit
#import mpld3
#mpld3.enable_notebook()

# %%
# %matplotlib inline
plt.rcParams.update({'font.size': 15})

# %%
df_calibration = pd.read_csv('GaussmeterCalibration.csv')
df_calibration = df_calibration.rename(columns={'-0.052': 'B Field', '-0.3137': "Voltage"})

def func(x, m, b):
    return m*x +b

(popt), pcov = curve_fit(func, df_calibration['Voltage'], df_calibration["B Field"])
 
plt.plot(df_calibration['Voltage'], func(df_calibration['Voltage'], *popt), '--',c='orange',label = f'B = {round(popt[0],4)}V {round(popt[1],4)}')
plt.scatter(df_calibration['Voltage'], df_calibration["B Field"],label='data')

m,b = popt

print(type(df_calibration["Voltage"]))
print(type(popt))
         
plt.xlabel("Voltage (V)")
plt.ylabel("H Magnetic Field (kG)")
plt.title("Gaussmeter Calibration")
plt.legend()
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
#### determinr HC at zero temperature and Tc by doing a fit 
files = glob.glob('*.txt')
files.sort()


list_samples = []
list_temperatures = []
list_critical_B = []

copper_dmdh = []
copper_temps = []

def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

for i, file in enumerate(files):   
    df = pd.read_table(file,names = ['v0','v1','v2','v3'])
    
    #dropping the second half of the sweep down (hysterisis) because the way down often doesn't even have a peak 
    try: 
        row_drop1 = df[df['v0']== max(df['v0'])].index[0]
    except IndexError: 
        row_drop1 = int(len(df['v0'])/2) #if there is an nan error, just takes the half of the length of the total series 

    row_drop2 = len(df['v0'])
    df = df.drop(labels=range(row_drop1, row_drop2), axis=0)
    
    df = df.dropna()
    df = m*df + b
    
    
    
    #finding second derivative in order to find the peaks in the voltage vs. magnetic field 
    first_derivative = df.diff(periods = 15)
#     MH = scipy.integrate.trapz(y=df['v1'],x=df['v0'])
    #second_derivative = first_derivative.diff(periods = 15)
    #df['2derivative'] = second_derivative['v1']
    df['1derivative'] = first_derivative['v1'] 
    #df['MH'] = MH
    ######df['smooth'] = df['v1'].rolling(window=10).mean()
    #df['smooth'] = scipy.signal.savgol_filter(df['v1'], 11, 3 )
    
    
    #peak_position = find_peaks(df['v1'], height = .001 , threshold = .001, distance = 400 )
    #peak_position = peak_position[0][0]
    #print(peak_position)
    
    
    peak_position = df['1derivative'].idxmax() #x axis position
    
    #peak_value_1 = df.nlargest(1, columns = "1derivative")
    #peak_value_2 = df.nlargest(2, columns = "1derivative" )
    #peak_position = df.loc[df['v1'] == peak_value_1]
    #peak_position_2 = df.loc[df['v1'] == peak_value_2]
    #print(peak_position)

    
    index1_temp = find_nth(file, "_", 2) + 1
    index2_temp = find_nth(file, "K", 1)
    
    index1_name = find_nth(file, "_", 1) + 1 
    index2_name = find_nth(file, "_", 2) 
    
    sample_temperature = file[index1_temp:index2_temp]
    sample_name = file[index1_name: index2_name]

    
    if sample_name == "PTFE" and index2_temp == -1:
        index1_temp = find_nth(file, "_", 2) + 1
        index2_temp = find_nth(file, "T", 2)
        sample_temperature = file[index1_temp:index2_temp]
        
        if float(sample_temperature) == 115e-1: 
            sample_temperature = 1.78
        elif float(sample_temperature) == 450: 
            sample_temperature = 3.7
 
    if index2_temp == -1: 
        index1_temp = find_nth(file, "_", 2) + 1
        index2_temp = find_nth(file, "T", 1)
        sample_temperature = file[index1_temp:index2_temp]

        if float(sample_temperature) == 115e-1: 
            sample_temperature = 1.78
        elif float(sample_temperature) == 450: 
            sample_temperature = 3.7
            
    if sample_name == 'Cu': 
        copper_temps.append(float(sample_temperature))
        copper_dmdh.append(float(df["v1"][10]))
        
    
    sample_temperature = float(sample_temperature)


    
    list_samples.append(sample_name)
    list_temperatures.append(sample_temperature)
    
    
    
    list_critical_B.append(df['v0'][peak_position])
    



#plt.close("all")
#print(list_critical_B)

# %%
{'IN': {'r': 0,
  'c': 0,
  'Hc1': 4.749878184089456,
  'Tc1': 3.352807442301161,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.10107204262581057,
  'Tc_sigma': 0.026196314783721024},
 'PB2': {'r': 0,
  'c': 1,
  'Hc1': 14.45422598611958,
  'Tc1': 7.645060765714264,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.035225303133826415,
  'Tc_sigma': 0.008746890365364633},
 'SNPB': {'r': 1,
  'c': 2,
  'Hc1': 19.676020154447567,
  'Tc1': 5.91906961779297,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.9489527700197797,
  'Tc_sigma': 0.3893991763034738},
 'IN2BI': {'r': 1,
  'c': 0,
  'Hc1': 9.190291154791153,
  'Tc1': 3.4482122059436175,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.08678270003776964,
  'Tc_sigma': 0.020921073240148316},
 'IN4BI': {'r': 1,
  'c': 1,
  'Hc1': 16.195950902860318,
  'Tc1': 3.9329235256209927,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.2613436488456486,
  'Tc_sigma': 0.026784788048471786},
 'SN': {'r': 0,
  'c': 2,
  'Hc1': 4.952248846831424,
  'Tc1': 3.808011084614157,
  'Hc2': None,
  'Tc2': None,
  'Hc_sigma': 0.17578239160629805,
  'Tc_sigma': 0.04390129052892687}}
# Out:
# {'IN': {'r': 0,
#   'c': 0,
#   'Hc1': 4.749878184089456,
#   'Tc1': 3.352807442301161,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.10107204262581057,
#   'Tc_sigma': 0.026196314783721024},
#  'PB2': {'r': 0,
#   'c': 1,
#   'Hc1': 14.45422598611958,
#   'Tc1': 7.645060765714264,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.035225303133826415,
#   'Tc_sigma': 0.008746890365364633},
#  'SNPB': {'r': 1,
#   'c': 2,
#   'Hc1': 19.676020154447567,
#   'Tc1': 5.91906961779297,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.9489527700197797,
#   'Tc_sigma': 0.3893991763034738},
#  'IN2BI': {'r': 1,
#   'c': 0,
#   'Hc1': 9.190291154791153,
#   'Tc1': 3.4482122059436175,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.08678270003776964,
#   'Tc_sigma': 0.020921073240148316},
#  'IN4BI': {'r': 1,
#   'c': 1,
#   'Hc1': 16.195950902860318,
#   'Tc1': 3.9329235256209927,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.2613436488456486,
#   'Tc_sigma': 0.026784788048471786},
#  'SN': {'r': 0,
#   'c': 2,
#   'Hc1': 4.952248846831424,
#   'Tc1': 3.808011084614157,
#   'Hc2': None,
#   'Tc2': None,
#   'Hc_sigma': 0.17578239160629805,
#   'Tc_sigma': 0.04390129052892687}}

# %%
def copper_abs_func(x,m, b):
    return m*x +b 

if copper_dmdh[1] < .1: 
    copper_dmdh[1]= copper_dmdh[1]*2
    copper_dmdh[2]= copper_dmdh[2]*2
print(copper_dmdh)
print(copper_temps)


popt, pcov = curve_fit(copper_abs_func, copper_temps, copper_dmdh)
plt.scatter(copper_temps, copper_dmdh)
plt.title("Copper Differential Magnetization")
plt.xlabel("Temperature (K)")
plt.ylabel("Differential Magnetization")

plt.savefig("Copper Linear")
m, b= popt
print(m)

def copper_dmdh_fit_subtraction(temperature, dmdh):
    dmdh = dmdh - (m*temperature + b ) 
    return dmdh
# Out:
# [0.18258746613202015, 0.18989081601542368, 0.19300258247741658, 0.19802589528898462, 0.19672932592982093, 0.19610526744596363]
# [1.78, 3.82, 3.82, 7.93, 7.93, 7.93]
# 0.0019583673630726643

# %%
files = glob.glob('*.txt')
files.sort()


list_samples = []
list_temperatures = []
list_critical_B = []



def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

for i, file in enumerate(files):   
    df = pd.read_table(file,names = ['v0','v1','v2','v3'])
    
    #dropping the second half of the sweep down (hysterisis) because the way down often doesn't even have a peak 
    try: 
        row_drop1 = df[df['v0']== max(df['v0'])].index[0]
    except IndexError: 
        row_drop1 = int(len(df['v0'])/2) #if there is an nan error, just takes the half of the length of the total series 

    row_drop2 = len(df['v0'])
    df = df.drop(labels=range(row_drop1, row_drop2), axis=0)
    
    df = df.dropna()
    df = m*df + b
    
    #print(df.keys())
    
    
    #finding second derivative in order to find the peaks in the voltage vs. magnetic field 
    
    
    #peak_value_1 = df.nlargest(1, columns = "1derivative")
    #peak_value_2 = df.nlargest(2, columns = "1derivative" )
    #peak_position = df.loc[df['v1'] == peak_value_1]
    #peak_position_2 = df.loc[df['v1'] == peak_value_2]
    #print(peak_position)

    
    index1_temp = find_nth(file, "_", 2) + 1
    index2_temp = find_nth(file, "K", 1)
    
    index1_name = find_nth(file, "_", 1) + 1 
    index2_name = find_nth(file, "_", 2) 
    
    sample_temperature = file[index1_temp:index2_temp]
    sample_name = file[index1_name: index2_name]

    
    if sample_name == "PTFE" and index2_temp == -1:
        index1_temp = find_nth(file, "_", 2) + 1
        index2_temp = find_nth(file, "T", 2)
        sample_temperature = file[index1_temp:index2_temp]
        
        if float(sample_temperature) == 115e-1: 
            sample_temperature = 1.78
        elif float(sample_temperature) == 450: 
            sample_temperature = 3.7
 
    if index2_temp == -1: 
        index1_temp = find_nth(file, "_", 2) + 1
        index2_temp = find_nth(file, "T", 1)
        sample_temperature = file[index1_temp:index2_temp]

        if float(sample_temperature) == 115e-1: 
            sample_temperature = 1.78
        elif float(sample_temperature) == 450: 
            sample_temperature = 3.7
        
    sample_temperature = float(sample_temperature)
    df['v1'] = copper_dmdh_fit_subtraction(sample_temperature, df['v1'])
        
    
    

    first_derivative = df.diff(periods = 15)
#     MH = scipy.integrate.trapz(y=df['v1'],x=df['v0'])
    #second_derivative = first_derivative.diff(periods = 15)
    #df['2derivative'] = second_derivative['v1']
    df['1derivative'] = first_derivative['v1'] 
    #df['MH'] = MH
    ######df['smooth'] = df['v1'].rolling(window=10).mean()
    #df['smooth'] = scipy.signal.savgol_filter(df['v1'], 11, 3 )
    
    
    #peak_position = find_peaks(df['v1'], height = .001 , threshold = .001, distance = 400 )
    #peak_position = peak_position[0][0]
    #print(peak_position)
    
    
    peak_position = df['1derivative'].idxmax() #x axis position
    
    list_samples.append(sample_name)
    list_temperatures.append(sample_temperature)
    
    
    
    list_critical_B.append(df['v0'][peak_position])
    

 
        
    fig = plt.figure()
    ax = fig.add_subplot(111)


            #df.plot(x = 'v0', y = ['v1'],label=['data'], linewidth=1, ax=ax)
                #df.plot(x = 'v0', y = ['v1', 'smooth', '2derivative'],label=['real', 'smooth', '2nd derivative'], linewidth=1, ax=ax)

    df.plot(x = 'v0', y = ['v1','1derivative'],label=['data','diff'], linewidth = 1, ax=ax)
#     df.plot(x = 'v0', y = ['MH'],label=['MH'], linewidth = 1, ax=ax)



            #     plt.plot(df['v0'][peak_position], df['v1'][peak_position], marker="o", markersize=3, markerfacecolor= "red", label = df['v0'][peak_position])
            #     plt.xlabel("Magnetic Field (Gauss)")
            #     plt.ylabel("-dM/dH")
            #     plt.annotate(str(df['v0'][peak_position]), (df['v0'][peak_position], df['v1'][peak_position]), ha = 'left')
            #     plt.xlim(left= 0)
            #     plt.title(sample_name + " at " + str(sample_temperature) + " K")

    ax.plot(df['v0'][peak_position], df['v1'][peak_position], marker="o", markersize=3, markerfacecolor= "red", label = df['v0'][peak_position])
    ax.set_xlabel("H Magnetic Field (kG)")
    ax.set_ylabel("-dM/dH")
    ax.annotate(str(round(df['v0'][peak_position], 3)) + " kG", (df['v0'][peak_position], df['v1'][peak_position]), ha = 'left')
        #ax.set_xlim(left= 0)
    ax.set_title(sample_name + " at " + str(sample_temperature) + " K ")

#plt.close("all")
#print(list_critical_B)
# Out:
# <ipython-input-30-d87a7a158eac>:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

# %%
## samples = ['IN','PB2','SNPB','IN2BI','IN4BI', 'SN'] #superconducting
#controls = ["PTFE", "Cu"] #non-superconducting


df_critical_B = pd.read_csv("MeissnerEffectData.csv")


df_critical_B_1 = df_critical_B[['Sample Name', 'Temperature (K)', 'Critical B Field 1']]
df_critical_B_1 = df_critical_B_1.dropna()

df_critical_B_2 = df_critical_B[['Sample Name', 'Temperature (K)', 'Critical B Field 2']]
df_critical_B_2 = df_critical_B_2.dropna()


print(df_critical_B_1)
print(df_critical_B_2)

def dict_temp_critical_B(df_critical_B):
    '''
    Params: dataframe of csv data (name, temp, critical B)
    Returns: Dictionary: Key are sample names. Values are two lists one of temp and one of critical B
    
    '''
    PB0 = [[], []]
    PB1 = [[], []]
    IN = [[], []]
    PB2 = [[], []]
    SNPB = [[], []]
    Cu = [[], []]
    PTFE = [[], []]
    IN2BI = [[], []]
    IN4BI = [[], []]
    SN = [[], []]

    all_samples = {"IN": IN, "PB2": PB2, "SNPB": SNPB, "Cu": Cu, "PTFE": PTFE, "IN2BI": IN2BI, "IN4BI": IN4BI, "SN": SN, "PB0": PB0, "PB1":PB1}
    for index, row in df_critical_B.iterrows(): #add some error bars 
        #print(row)
        key = row["Sample Name"]
        sample = all_samples[key.strip()]
        #print(sample)
        sample[0].append(row['Temperature (K)'])
        try: 
            sample[1].append(row['Critical B Field 1'])
        except KeyError: 
            sample[1].append(row['Critical B Field 2'])
    
    return all_samples


first_curve_samples = dict_temp_critical_B(df_critical_B_1) #moving all csv data into dictionary
print(first_curve_samples)
second_curve_samples = dict_temp_critical_B(df_critical_B_2)
print(second_curve_samples)


# r, c, Hc1, Tc1, Hc2, Tc2
subplots = {"IN": {'r':0,'c':0,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}, 
            "PB2": {'r':0,'c':1,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}, 
            "SNPB": {'r':1,'c':2,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}, 
            "IN2BI": {'r':1,'c':0,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}, 
            "IN4BI": {'r':1,'c':1,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}, 
            "SN": {'r':0,'c':2,'Hc1':None,'Tc1':None,'Hc2':None,'Tc2':None}}
# def plot_sample_dict(all_samples):

def Hc_from_Tc(T, Hc0, Tc0):
    return Hc0*(1-(T/Tc0)**2)

fig, axes = plt.subplots(2, 3, figsize=(10,5))

for key in subplots:
    #print(key)
    #print(all_samples[key][0])

    if key not in ["PB0", "PB1", "PTFE", "Cu"]: #excluding the non-superconducting samples or the samples we don't want to look at
        
        r = subplots[key]['r']
        c = subplots[key]['c']
        ax = axes[r,c]
        
        for n, data in {1:first_curve_samples, 2:second_curve_samples}.items():
            x_meissner = data[key][0]
            y_meissner = data[key][1]

            if len(x_meissner) != 0:
                x_meissner = pd.Series(x_meissner)
                y_meissner = pd.Series(y_meissner)

                sigma = []
                for i in range(len(x_meissner)):
                    sigma.append(.1)

                sigma = pd.Series(sigma)
                popt, pcov = curve_fit(Hc_from_Tc, x_meissner, y_meissner, p0=(10,3),sigma=sigma)
                Hc0, Tc0 = popt
                Hc_sigma, Tc_sigma = np.sqrt(np.diag(pcov))
                if n == 1:
                    subplots[key]['Hc1'] = Hc0
                    subplots[key]['Tc1'] = Tc0
                    subplots[key]['Hc_sigma1'] = Hc_sigma
                    subplots[key]['Tc_sigma1'] = Tc_sigma
                if n == 2:
                    subplots[key]['Hc2'] = Hc0
                    subplots[key]['Tc2'] = Tc0
                    subplots[key]['Hc_sigma2'] = Hc_sigma
                    subplots[key]['Tc_sigma2'] = Tc_sigma

#                     popt, pcov = curve_fit(Hc_from_T, x_meissner, y_meissner, p0=(10,3),sigma=sigma)
#                     Hc0, Tc0 = popt
#                     subplots[key]['Hc2'] = Hc0
#                     subplots[key]['Tc2'] = Tc0
                
                xrange = np.linspace(0,Tc0,50)
                ax.plot(xrange, Hc_from_T(xrange, Hc0, Tc0),'--')
                ax.errorbar(x_meissner, y_meissner, ls='none', yerr= .1, fmt='o', alpha = 0.5, label=key+f' {n}')
#                 ax.scatter(x_meissner, y_meissner, s=10 , color = 'red',zorder=100)

        #         -b/m = x

#                 print(key, "Critical B Field at Zero Temperature", func(0, Hc0, Tc0) )
#                 print(key, "Critical Temperature with Zero B Field ", -popt[1]/popt[0])
                if key in real_vals.keys():
                    Hc_r, Tc_r = real_vals[key][2]*(4*np.pi)/1000,real_vals[key][0]
                    theoretical = Hc_from_Tc(xrange,Hc_r,Tc_r)
                    ax.plot(xrange, theoretical, '--',label='Literature')
                if n == 1:
                    ax.annotate(f'$H_c = {round(Hc0,4)}$', (0.1,0.2), xycoords='axes fraction',size=10)
                    ax.annotate(f'$T_c = {round(Tc0,4)}$', (0.1,0.1), xycoords='axes fraction', size=10)
                if n == 2:
                    ax.annotate(f'$H_c2 = {round(Hc0,4)}$', (0.1,0.3), xycoords='axes fraction',size=10)
                    ax.annotate(f'$T_c2 = {round(Tc0,4)}$', (0.1,0.4), xycoords='axes fraction', size=10)
#                 plt.xlabel("Temperature (K)")
#                 plt.ylabel("Critical B Field (kG)")
#                 plt.title(key)
                ax.legend(fontsize=10)
#                 ax.set_xlim(0,4.5)
#                 ax.set_ylim(0,17)
            else: 
                pass 
plt.tight_layout()
# plt.legend()
# Out:
#     Sample Name  Temperature (K)  Critical B Field 1
# 0         IN2BI             1.78            4.456123
# 1         IN2BI             1.78            4.492552
# 2            IN             1.78            3.369994
# 3            IN             1.78            3.411801
# 4            IN             1.78            3.407584
# ..          ...              ...                 ...
# 97         SNPB             2.66           12.572000
# 99         SNPB             3.51           11.227244
# 100        SNPB             3.51           11.286931
# 104          SN             3.55            1.012171
# 105          SN             3.70            1.019351
#
# [71 rows x 3 columns]
#     Sample Name  Temperature (K)  Critical B Field 2
# 0         IN2BI             1.78            6.701000
# 1         IN2BI             1.78            6.662000
# 23        IN2BI             1.78            6.861000
# 24        IN4BI             1.78           12.810264
# 25        IN4BI             3.55            2.993888
# 49        IN2BI             2.66            3.736000
# 50        IN2BI             2.66            3.700000
# 51        IN2BI             2.66            3.728000
# 61        IN4BI             1.78           12.877000
# 62        IN4BI             1.78           13.140500
# 63        IN4BI             1.78           13.273000
# 64        IN4BI             2.66            7.789090
# 65        IN4BI             3.52            3.205557
# 66        IN4BI             3.52            3.155170
# 67        IN4BI             3.52            3.249847
# 68        IN4BI             3.52            3.307000
# 69        IN4BI             3.56            3.315100
# 95         SNPB             2.66           16.335000
# 96         SNPB             2.66           14.952000
# 97         SNPB             2.66           15.820000
# 99         SNPB             3.51           12.705000
# 100        SNPB             3.51           12.809000
# {'IN': [[1.78, 1.78, 1.78, 3.03, 3.03, 2.66, 2.66, 2.66, 2.85, 3.04], [3.369994425, 3.411800525, 3.407584421, 0.797585884, 0.801528589, 1.887930785, 1.884175143, 1.570087395, 1.444669096, 0.842471322]], 'PB2': [[7.03, 7.03, 7.03, 7.03, 7.03, 4.03, 4.03, 4.03, 2.66, 2.66, 2.66, 7.03], [2.222058217, 2.226653243, 2.237080785, 2.250616445, 2.24608857, 10.35497058, 10.35451971, 10.33619237, 12.77504778, 12.74871512, 12.79912131, 2.268560068]], 'SNPB': [[4.03, 4.03, 2.66, 2.66, 2.66, 3.51, 3.51], [10.10935255, 10.04843728, 12.572, 12.5753944, 12.572, 11.22724362, 11.28693099]], 'Cu': [[], []], 'PTFE': [[], []], 'IN2BI': [[1.78, 1.78, 1.78, 2.66, 2.66, 2.66, 3.52, 3.52, 3.52, 3.52, 3.52], [4.456123222, 4.49255247, 4.475865524, 2.473719808, 2.438441715, 2.455474007, 0.638544277, 0.738028021, 0.902930924, 0.926102707, 0.947878716]], 'IN4BI': [[1.78, 3.55, 1.78, 1.78, 1.78, 2.66, 3.52, 3.52, 3.52, 3.52, 3.56], [4.766, 1.194, 4.671820823, 4.653421535, 4.79212128, 3.249, 1.465, 1.63, 1.548, 1.346705836, 1.269415394]], 'SN': [[1.78, 2.7, 2.7, 3.51, 3.51, 3.51, 3.7, 3.7, 1.78, 1.78, 2.7, 2.7, 2.7, 2.79, 3.55, 3.55, 3.7], [3.941533113, 2.283846443, 2.290882875, 0.500453685, 0.50472255, 0.501336236, 0.272328409, 0.211993517, 3.95964941, 3.965385997, 2.331830405, 2.355644917, 2.708963056, 2.364268984, 0.35514919, 1.012170703, 1.01935103]], 'PB0': [[4.04, 4.04, 4.04], [10.38565844, 10.35838567, 10.3851692]], 'PB1': [[], []]}
# {'IN': [[], []], 'PB2': [[], []], 'SNPB': [[2.66, 2.66, 2.66, 3.51, 3.51], [16.335, 14.952, 15.82, 12.705, 12.809]], 'Cu': [[], []], 'PTFE': [[], []], 'IN2BI': [[1.78, 1.78, 1.78, 2.66, 2.66, 2.66], [6.701, 6.662, 6.861, 3.736, 3.7, 3.728]], 'IN4BI': [[1.78, 3.55, 1.78, 1.78, 1.78, 2.66, 3.52, 3.52, 3.52, 3.52, 3.56], [12.81026352, 2.99388822, 12.877, 13.1405, 13.273, 7.789090044, 3.205556781, 3.155169783, 3.249847456, 3.307, 3.3151]], 'SN': [[], []], 'PB0': [[], []], 'PB1': [[], []]}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5497aba09a8b> in <module>
#     111
#     112                 xrange = np.linspace(0,Tc0,50)
# --> 113                 ax.plot(xrange, Hc_from_T(xrange, Hc0, Tc0),'--')
#     114                 ax.errorbar(x_meissner, y_meissner, ls='none', yerr= .1, fmt='o', alpha = 0.5, label=key+f' {n}')
#     115 #                 ax.scatter(x_meissner, y_meissner, s=10 , color = 'red',zorder=100)
#
# NameError: name 'Hc_from_T' is not defined

# %%
subplots

# %%
# %matplotlib widget

# %%
real_vals = {"IN": [3.408,0.001,281.5,2],
            "PB2": [7.196,0.006,803,1],
            "SN": [3.722, 0.001, 305, 2]}

# %%
# Hc0 - Hc0*T**2/(Tc0**2)

# %%
def errors(Hc_sigma, Tc_sigma, Hc, Tc):
    return np.sqrt(Hc_sigma**2 + (Tc_sigma/Tc)**2 + (Tc_sigma/Tc)**2 + (Hc_sigma/Hc)**2)

# %%
fig, axes = plt.subplots(2, 3, figsize=(10,5))

for key in all_samples:
    #print(key)
    #print(all_samples[key][0])

    if key not in ["PB0", "PB1", "PTFE", "Cu"]: #excluding the non-superconducting samples or the samples we don't want to look at
        
        r = subplots[key]['r']
        c = subplots[key]['c']
        ax = axes[r,c]
        
        for n, data in {1:first_curve_samples, 2:second_curve_samples}.items():
            x_meissner = data[key][0]
            y_meissner = (data[key][1])

            if len(x_meissner) != 0:
                x_meissner = pd.Series(x_meissner)
                y_meissner = pd.Series(y_meissner)

                sigma = []
                for i in range(len(x_meissner)):
                    sigma.append(.1)

                sigma = pd.Series(sigma)
                if subplots[key]['Tc2'] == None:
#                 if n == 1:
#                     popt, pcov = curve_fit(Hc_from_Tc, x_meissner, y_meissner, p0=(10,3),sigma=sigma)
                    Hc0, Tc0 = subplots[key]['Hc1'], subplots[key]['Tc1']
                    Hc_sigma, Tc_sigma = subplots[key]['Hc_sigma1'], subplots[key]['Tc_sigma1']
#                     subplots[key]['Hc1'] = Hc0
#                     subplots[key]['Tc1'] = Tc0
                else:
#                 if n == 2:
                    Tc0 = (subplots[key]['Tc1'] + subplots[key]['Tc2']) / 2.
                    Tc_sigma = (subplots[key]['Tc_sigma1'] + subplots[key]['Tc_sigma2'])
                    popt, pcov = curve_fit(lambda x, a: Hc_from_Tc(x, a, Tc0), x_meissner, y_meissner,sigma=sigma)
                    Hc0 = popt[0]
                    Hc_sigma = np.sqrt(np.diag(pcov))[0]

#                     popt, pcov = curve_fit(Hc_from_T, x_meissner, y_meissner, p0=(10,3),sigma=sigma)
#                     Hc0, Tc0 = popt
#                     subplots[key]['Hc2'] = Hc0
#                     subplots[key]['Tc2'] = Tc0

                error = errors(Hc_sigma, Tc_sigma, Hc0, Tc0)
                xrange = np.linspace(0,Tc0,50)
                fit = Hc_from_T(xrange, Hc0, Tc0)
                ax.plot(xrange, fit ,'--')
                ax.fill_between(xrange, fit-error, fit+error,alpha=0.5)
                
                ax.errorbar(x_meissner, y_meissner, ls='none', yerr= .1, fmt='o', alpha = 0.5, label=key+f' {n}')
#                 ax.scatter(x_meissner, y_meissner, s=10 , color = 'red',zorder=100)

        #         -b/m = x

#                 print(key, "Critical B Field at Zero Temperature", func(0, Hc0, Tc0) )
#                 print(key, "Critical Temperature with Zero B Field ", -popt[1]/popt[0])
                if key in real_vals.keys():
                    Hc_r, Tc_r = real_vals[key][2]/1000,real_vals[key][0]
                    theoretical = Hc_from_Tc(xrange,Hc_r,Tc_r)
#                     ax.plot(xrange, theoretical, '--',label='Literature')
                    print(key,real_vals[key][2]/1000,Hc0,real_vals[key][2]/1000/Hc0, real_vals[key][0])
                if n == 1:
                    ax.annotate(f'$H_c = {round(Hc0,4)}$', (0.1,0.2), xycoords='axes fraction',size=10)
                    ax.annotate(f'$T_c = {round(Tc0,4)}$', (0.1,0.1), xycoords='axes fraction', size=10)
                if n == 2:
                    ax.annotate(f'$H_c2 = {round(Hc0,4)}$', (0.1,0.3), xycoords='axes fraction',size=10)
#                     ax.annotate(f'$T_c2 = {round(Tc0,4)}$', (0.1,0.3), xycoords='axes fraction', size=10)
#                 plt.xlabel("Temperature (K)")
#                 plt.ylabel("Critical B Field (kG)")
#                 plt.title(key)
                ax.legend(fontsize=10)
#                 ax.set_xlim(0,4.5)
#                 ax.set_ylim(0,17)
            else: 
                pass 
plt.tight_layout()
# plt.legend()

# %%
14.4/4/np.pi

# %%
perr = np.sqrt(np.diag(pcov))

# %%
perr

# %%
print("start of type 2 samples")
plot_sample_dict(second_curve_samples)

# %%
        x_meissner_array = np.array(x_meissner)
        y_meissner_array = np.array(y_meissner)
        #print(x_meissner_array)
        #print(y_meissner_array)
        #print(len(x_meissner_array))
        #print(len(y_meissner_array))
        
        x_meissner_array = x_meissner_array.reshape(-1, 1)
        y_meissner_array = y_meissner_array.reshape(-1, 1)
        
        fit = LinearRegression().fit(x_meissner_array, y_meissner_array)  # perform linear regression
        y_pred_meissner_array = fit.predict(x_meissner_array)  # make predictions
        plt.plot(x_meissner_array, y_pred_meissner_array, color='purple', linewidth = 1 )
        plt.errorbar(x_meissner, y_meissner, yerr = .1, xerr = .1) #what is the error on the calibration????
        m_meissner = float(fit.coef_)
        b_meissner = float(fit.intercept_)
