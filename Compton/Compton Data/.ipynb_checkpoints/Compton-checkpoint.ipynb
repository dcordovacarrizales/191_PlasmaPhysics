# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cobalt =np.loadtxt('CobaltCalibration16gain610volts120sec.Spe',skiprows=12, max_rows=1023)
cobalt =np.loadtxt('CobaltCalibration16gain610volts120sec.Spe',skiprows=12, max_rows=1023)
cobalt =np.loadtxt('CobaltCalibration16gain610volts120sec.Spe',skiprows=12, max_rows=1023)
cobalt =np.loadtxt('CobaltCalibration16gain610volts120sec.Spe',skiprows=12, max_rows=1023)

# %%
cobalt
# Out:
# array([0., 0., 0., ..., 2., 2., 0.])

# %%
len(cobalt)
# Out:
# 1023

# %%
plt.plot(cobalt)
